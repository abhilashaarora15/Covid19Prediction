# %% [markdown]
# <a href="https://colab.research.google.com/github/abhilashaarora15/Covid19Prediction/blob/main/Covid19_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data Manipulation and Data Visualization ###

# %%
df=pd.read_csv("/content/covid.csv")
df.head()
# Out:
#   iso_code location  ... handwashing_facilities  hospital_beds_per_100k
# 0      ABW    Aruba  ...                    NaN                     NaN
# 1      ABW    Aruba  ...                    NaN                     NaN
# 2      ABW    Aruba  ...                    NaN                     NaN
# 3      ABW    Aruba  ...                    NaN                     NaN
# 4      ABW    Aruba  ...                    NaN                     NaN
#
# [5 rows x 32 columns]

# %%
df.tail()
# Out:
#       iso_code       location  ... handwashing_facilities  hospital_beds_per_100k
# 19491      NaN  International  ...                    NaN                     NaN
# 19492      NaN  International  ...                    NaN                     NaN
# 19493      NaN  International  ...                    NaN                     NaN
# 19494      NaN  International  ...                    NaN                     NaN
# 19495      NaN  International  ...                    NaN                     NaN
#
# [5 rows x 32 columns]

# %%
df.shape
# Out:
# (19496, 32)

# %%
df.columns
# Out:
# Index(['iso_code', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'total_cases_per_million',
#        'new_cases_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'tests_units',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cvd_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_100k'],
#       dtype='object')

# %%
df.isna().any()
# Out:
# iso_code                            True
# location                           False
# date                               False
# total_cases                        False
# new_cases                          False
# total_deaths                       False
# new_deaths                         False
# total_cases_per_million             True
# new_cases_per_million               True
# total_deaths_per_million            True
# new_deaths_per_million              True
# total_tests                         True
# new_tests                           True
# total_tests_per_thousand            True
# new_tests_per_thousand              True
# new_tests_smoothed                  True
# new_tests_smoothed_per_thousand     True
# tests_units                         True
# stringency_index                    True
# population                          True
# population_density                  True
# median_age                          True
# aged_65_older                       True
# aged_70_older                       True
# gdp_per_capita                      True
# extreme_poverty                     True
# cvd_death_rate                      True
# diabetes_prevalence                 True
# female_smokers                      True
# male_smokers                        True
# handwashing_facilities              True
# hospital_beds_per_100k              True
# dtype: bool

# %%
df.isna().sum()
# Out:
# iso_code                              64
# location                               0
# date                                   0
# total_cases                            0
# new_cases                              0
# total_deaths                           0
# new_deaths                             0
# total_cases_per_million              377
# new_cases_per_million                377
# total_deaths_per_million             377
# new_deaths_per_million               377
# total_tests                        14332
# new_tests                          14904
# total_tests_per_thousand           14332
# new_tests_per_thousand             14904
# new_tests_smoothed                 13866
# new_tests_smoothed_per_thousand    13866
# tests_units                        13267
# stringency_index                    4500
# population                            64
# population_density                   850
# median_age                          1743
# aged_65_older                       1980
# aged_70_older                       1832
# gdp_per_capita                      1982
# extreme_poverty                     7878
# cvd_death_rate                      1817
# diabetes_prevalence                 1174
# female_smokers                      5052
# male_smokers                        5206
# handwashing_facilities             11822
# hospital_beds_per_100k              3160
# dtype: int64

# %%
nedf=df.dropna()
nedf.head()
nedf.isna().sum()
# Out:
# iso_code                           0
# location                           0
# date                               0
# total_cases                        0
# new_cases                          0
# total_deaths                       0
# new_deaths                         0
# total_cases_per_million            0
# new_cases_per_million              0
# total_deaths_per_million           0
# new_deaths_per_million             0
# total_tests                        0
# new_tests                          0
# total_tests_per_thousand           0
# new_tests_per_thousand             0
# new_tests_smoothed                 0
# new_tests_smoothed_per_thousand    0
# tests_units                        0
# stringency_index                   0
# population                         0
so_code location  ... handwashing_facilities  hospital_beds_per_100k
# 8518      IND    India  ...                  59.55                    0.53
# 8519      IND    India  ...                  59.55                    0.53
# 8520      IND    India  ...                  59.55                    0.53
# 8521      IND    India  ...                  59.55                    0.53
# 8522      IND    India  ...                  59.55                    0.53
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Total Cases Per Day

# %%
#Total cases per day
sns.set(rc={'figure.figsize':(15,15)})
sns.lineplot(x="date",y="total_cases",data=india_case)
plt.show()

# %%
#Taking a database for last 5 days
sns.set(rc={'figure.figsize':(15,15)})
sns.lineplot(x="date",y="total_cases",data=india_case_last_5_days)
plt.show()

# %% [markdown]
# ### Total Tests Per Day

# %%
#Total tests per day
sns.set(rc={'figure.figsize':(15,15)})
sns.lineplot(x="date",y="total_tests",data=india_case)
plt.show()

# %%
#Total Tests nin last 5 days
sns.set(rc={'figure.figsize':(15,15)})
sns.lineplot(x="date",y="total_cases",data=india_case_last_5_days)
plt.show()

# %% [markdown]
# ### Condition Of Brazil

# %%
#Brazil Case
brazil_case=df[df["location"]=="Brazil"] 
brazil_case.head()
# Out:
#      iso_code location  ... handwashing_facilities  hospital_beds_per_100k
# 2510      BRA   Brazil  ...                    NaN                     2.2
# 2511      BRA   Brazil  ...                    NaN                     2.2
# 2512      BRA   Brazil  ...                    NaN                     2.2
# 2513      BRA   Brazil  ...                    NaN                     2.2
# 2514      BRA   Brazil  ...                    NaN                     2.2
#
# [5 rows x 32 columns]

# %%
brazil_case.tail()
# Out:
#      iso_code location  ... handwashing_facilities  hospital_beds_per_100k
# 2651      BRA   Brazil  ...                    NaN                     2.2
# 2652      BRA   Brazil  ...                    NaN                     2.2
# 2653      BRA   Brazil  ...                    NaN                     2.2
# 2654      BRA   Brazil  ...                    NaN                     2.2
# 2655      BRA   Brazil  ...                    NaN                     2.2
#
# [5 rows x 32 columns]

# %%
#Making a dataframe for brazil for last 5 days
brazil_last_5_days=brazil_case.tail()

# %%
#Total cases in last 5 days
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_cases",data=brazil_last_5_days)
plt.show()

# %% [markdown]
# ### Understanding cases of India, China and Japan

# %%
#Understanding cases of India, China and Japan
india_japan_china=df[(df["location"] =="India") | (df["location"] =="China") | (df["location"]=="Japan")]

# %% [markdown]
# ### Plotting growth of cases across China, India and Japan

# %%
#Plotting growth of cases across China, India and Japan
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="location",y="total_cases",data=india_japan_china,hue="date")
plt.show()

# %% [markdown]
# ### Understanding cases of germany and spain

# %%
#Understanding cases of germany and spain
germany_spain=df[(df["location"] =="Germany") | (df["location"] =="Spain")]

# %% [markdown]
# ### Plotting growth of cases across Germany and Spain

# %%
#Plotting growth of cases across Germany and Spain
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="location",y="total_cases",data=germany_spain,hue="date")
plt.show()

# %%
last_day_cases=df[df["date"]=="2020-05-24"]
last_day_cases
# Out:
#        iso_code      location  ... handwashing_facilities  hospital_beds_per_100k
# 62          ABW         Aruba  ...                    NaN                     NaN
# 198         AFG   Afghanistan  ...                 37.746                   0.500
# 262         AGO        Angola  ...                 26.664                     NaN
# 321         AIA      Anguilla  ...                    NaN                     NaN
# 398         ALB       Albania  ...                    NaN                   2.890
# ...         ...           ...  ...                    ...                     ...
# 19045       YEM         Yemen  ...                 49.542                   0.700
# 19153       ZAF  South Africa  ...                 43.993                   2.320
# 19220       ZMB        Zambia  ...                 13.938                   2.000
# 19285       ZWE      Zimbabwe  ...                 36.791                   1.700
# 19431  OWID_WRL         World  ...                 60.130                   2.705
#
# [207 rows x 32 columns]

# %% [markdown]
# ### Sorting data w.r.t total_cases

# %%
#Sorting data w.r.t total_cases
max_cases_country=last_day_cases.sort_values(by="total_cases",ascending=False)
max_cases_country
# Out:
#        iso_code  ... hospital_beds_per_100k
# 19431  OWID_WRL  ...                  2.705
# 18391       USA  ...                  2.770
# 2655        BRA  ...                  2.200
# 15569       RUS  ...                  8.050
# 9396        ITA  ...                  3.180
# ...         ...  ...                    ...
# 18723       VGB  ...                    NaN
# 1645        BES  ...                    NaN
# 5543        ESH  ...                    NaN
# 321         AIA  ...                    NaN
# 11086       LSO  ...                    NaN
#
# [207 rows x 32 columns]

# %% [markdown]
# ### Top 5 countries with Maximum Cases

# %%
#Top 5 countries with maximum cases
max_cases_country[1:6]
# Out:
#        iso_code       location  ... handwashing_facilities  hospital_beds_per_100k
# 12476  OWID_WRL          World  ...                  60.13                   2.705
# 24152       USA  United States  ...                    NaN                   2.770
# 11436       USA  United States  ...                    NaN                   2.770
# 2655        BRA         Brazil  ...                    NaN                   2.200
# 8614        RUS         Russia  ...                    NaN                   8.050
#
# [5 rows x 32 columns]

# %%
#Making bar-plot for countries with top cases
sns.barplot(x="location",y="total_cases",data=max_cases_country[1:6],hue="location")
plt.show()

# %%
india_case.head()
# Out:
#       iso_code location  ... handwashing_facilities  hospital_beds_per_100k
# 14140      IND    India  ...                  59.55                    0.53
# 14141      IND    India  ...                  59.55                    0.53
# 14142      IND    India  ...                  59.55                    0.53
# 14143      IND    India  ...                  59.55                    0.53
# 14144      IND    India  ...                  59.55                    0.53
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Linear REgression

# %%
#Linear regression
from sklearn.model_selection import train_test_split

# %%
#converting string date to date-time
import datetime as dt
india_case['date'] = pd.to_datetime(india_case['date']) 
india_case.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       iso_code location  ... handwashing_facilities  hospital_beds_per_100k
# 14140      IND    India  ...                  59.55                    0.53
# 14141      IND    India  ...                  59.55                    0.53
# 14142      IND    India  ...                  59.55                    0.53
# 14143      IND    India  ...                  59.55                    0.53
# 14144      IND    India  ...                  59.55                    0.53
#
# [5 rows x 32 columns]

# %%
#converting date-time to ordinal
india_case['date']=india_case['date'].map(dt.datetime.toordinal)
india_case.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       iso_code location  ...  handwashing_facilities  hospital_beds_per_100k
# 14140      IND    India  ...                   59.55                    0.53
# 14141      IND    India  ...                   59.55                    0.53
# 14142      IND    India  ...                   59.55                    0.53
# 14143      IND    India  ...                   59.55                    0.53
# 14144      IND    India  ...                   59.55                    0.53
#
# [5 rows x 32 columns]

# %%
#getting dependent variable and inpedent variable
x=india_case['date']
y=india_case['total_cases']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
india_case.tail()
# Out:
#       iso_code location  ...  handwashing_facilities  hospital_beds_per_100k
# 14280      IND    India  ...                   59.55                    0.53
# 14281      IND    India  ...                   59.55                    0.53
# 14282      IND    India  ...                   59.55                    0.53
# 14283      IND    India  ...                   59.55                    0.53
# 14284      IND    India  ...                   59.55                    0.53
#
# [5 rows x 32 columns]

# %%
y_pred=lr.predict(np.array(x_test).reshape(-1,1))

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(x_test,y_pred)
lr.predict(np.array([[737573]]))
# Out:
# array([[54991.42433876]])
